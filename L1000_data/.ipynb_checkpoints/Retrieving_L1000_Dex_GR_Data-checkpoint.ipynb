# %%
import json
import requests
import pandas as pd

# %%
metadata_api = "https://maayanlab.cloud/sigcom-lincs/metadata-api"

# %%
payload = {
    "filter": {
        "where": {
            "meta": {
                "fullTextSearch": "Chemical Perturbation 2021"
            }
        }
    }
}

res = requests.post(metadata_api + "/libraries/find", json=payload)
res.json()

chem_pert_dataset = res.json()[0]
dataset = chem_pert_dataset['dataset']

# %%
libid = chem_pert_dataset["id"]
payload = {
    "filter": {
        "where": {
            "meta.pert_name": "dexamethasone",
            "library": libid
        }
    }
}

res = requests.post(metadata_api + "/signatures/find", json=payload)
dex_signatures = res.json()
# Out:
# [{'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '91c33a2f-b9b1-5aee-ade7-ec52a445c916',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': 'f8550c4ae170d84a47b2e315d75bfc64',
#    'doid': 'DOID:1324',
#    'sha256': '3c4397b55647dea09adaa12853f102ceafdf5ca120ad8cbfa941262f319e6a1a',
#    'tissue': 'lung',
#    'anatomy': 'UBERON:0002048',
#    'cmap_id': 'LKCP002_A549_48H:E08',
#    'disease': 'lung cancer',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_LKCP002_A549_48H_E08_dexamethasone_1.11uM.tsv',
#    'local_id': 'LKCP002_A549_48H_E08_dexamethasone_1.11uM',
#    'cell_line': 'A549',
#    'pert_dose': '1.11 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '48 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-19',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_LKCP002_A549_48H_E08_dexamethasone_1.11uM.tsv',
#    'size_in_bytes': 217006,
#    'uncompressed_size_in_bytes': 217006}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '1e705bc4-fa51-5272-871c-929801760c3c',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '2bae292caf243ab06cdca3d23e060937',
#    'doid': 'DOID:1324',
#    'sha256': 'b3affb611b35f05d83e2942f2724aac78c39fae18121e99bd2e18c67e4087a66',
#    'tissue': 'lung',
#    'anatomy': 'UBERON:0002048',
#    'cmap_id': 'LKCP002_A549_48H:E07',
#    'disease': 'lung cancer',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_LKCP002_A549_48H_E07_dexamethasone_10uM.tsv',
#    'local_id': 'LKCP002_A549_48H_E07_dexamethasone_10uM',
#    'cell_line': 'A549',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '48 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-19',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_LKCP002_A549_48H_E07_dexamethasone_10uM.tsv',
#    'size_in_bytes': 217203,
#    'uncompressed_size_in_bytes': 217203}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '4a237049-1aef-5267-8ced-3ec81f3b13fc',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': 'e18ffc8a744b1db9a2faa77b0ff21073',
#    'doid': 'DOID:1324',
#    'sha256': 'eb7b7b6d55ffa3b7449fc032cc0f76e936788c4b2a856d7d640b3345e1faeca4',
#    'tissue': 'lung',
#    'anatomy': 'UBERON:0002048',
#    'cmap_id': 'LKCP002_A549_24H:E08',
#    'disease': 'lung cancer',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_LKCP002_A549_24H_E08_dexamethasone_1.11uM.tsv',
#    'local_id': 'LKCP002_A549_24H_E08_dexamethasone_1.11uM',
#    'cell_line': 'A549',
#    'pert_dose': '1.11 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-19',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_LKCP002_A549_24H_E08_dexamethasone_1.11uM.tsv',
#    'size_in_bytes': 216777,
#    'uncompressed_size_in_bytes': 216777}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': 'bb886c5d-5d22-53d1-8cd4-3e5d746bcbcb',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': 'bd9869e44fcf0e72e9b4629cf1a59e95',
#    'doid': 'DOID:1324',
#    'sha256': '378fbed02e85b3421aea70b7b7224f955a7d2be5bcb4f56c7a7a53f0cd54cc1c',
#    'tissue': 'lung',
#    'anatomy': 'UBERON:0002048',
#    'cmap_id': 'LKCP002_A549_6H:E09',
#    'disease': 'lung cancer',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_LKCP002_A549_6H_E09_dexamethasone_0.12uM.tsv',
#    'local_id': 'LKCP002_A549_6H_E09_dexamethasone_0.12uM',
#    'cell_line': 'A549',
#    'pert_dose': '0.12 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '6 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-19',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_LKCP002_A549_6H_E09_dexamethasone_0.12uM.tsv',
#    'size_in_bytes': 217204,
#    'uncompressed_size_in_bytes': 217204}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': 'b1d8089d-a2e3-50ef-b95c-7816a3ee6276',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '7c016384dc50ba68fb56184c071c2641',
#    'doid': 'DOID:1324',
#    'sha256': '2c25590f9a53fb807623976f7108a2f08875907089104327caf224b4c75707df',
#    'tissue': 'lung',
#    'anatomy': 'UBERON:0002048',
#    'cmap_id': 'LKCP002_A549_6H:E07',
#    'disease': 'lung cancer',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_LKCP002_A549_6H_E07_dexamethasone_10uM.tsv',
#    'local_id': 'LKCP002_A549_6H_E07_dexamethasone_10uM',
#    'cell_line': 'A549',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '6 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-19',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_LKCP002_A549_6H_E07_dexamethasone_10uM.tsv',
#    'size_in_bytes': 217082,
#    'uncompressed_size_in_bytes': 217082}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '3b8e7f80-bbae-5674-a233-ba58aad0f1dc',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '43a561f22e58e4f6ce2dca32a275174b',
#    'doid': 'DOID:1324',
#    'sha256': 'ea6b1bd6e6ed33ff834e543cfdb52ea38800bbdcebf626186b958c1df1e7850a',
#    'tissue': 'lung',
#    'anatomy': 'UBERON:0002048',
#    'cmap_id': 'LKCP002_A549_24H:E07',
#    'disease': 'lung cancer',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_LKCP002_A549_24H_E07_dexamethasone_10uM.tsv',
#    'local_id': 'LKCP002_A549_24H_E07_dexamethasone_10uM',
#    'cell_line': 'A549',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-19',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_LKCP002_A549_24H_E07_dexamethasone_10uM.tsv',
#    'size_in_bytes': 216767,
#    'uncompressed_size_in_bytes': 216767}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': 'f811509c-b2cb-588a-922d-06a7e25988f0',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '5fe1c153290408fd7dcf72d396dcd3f5',
#    'doid': 'DOID:1324',
#    'sha256': '08b089840c0563ae90a5563589ed87413f04719be1c305422984b21acd197229',
#    'tissue': 'lung',
#    'anatomy': 'UBERON:0002048',
#    'cmap_id': 'LKCP002_A549_48H:E09',
#    'disease': 'lung cancer',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_LKCP002_A549_48H_E09_dexamethasone_0.12uM.tsv',
#    'local_id': 'LKCP002_A549_48H_E09_dexamethasone_0.12uM',
#    'cell_line': 'A549',
#    'pert_dose': '0.12 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '48 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-19',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_LKCP002_A549_48H_E09_dexamethasone_0.12uM.tsv',
#    'size_in_bytes': 217049,
#    'uncompressed_size_in_bytes': 217049}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '323d37ff-6402-550d-aa12-4862363d4064',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': 'f23a01854da77a453f606b0d95668a02',
#    'doid': 'DOID:1324',
#    'sha256': '3fef87891132d4e4f647c0cf54a8867ae2d75ffa3a339fcba1fa3e0d1e07b3dd',
#    'tissue': 'lung',
#    'anatomy': 'UBERON:0002048',
#    'cmap_id': 'LKCP002_A549_24H:E09',
#    'disease': 'lung cancer',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_LKCP002_A549_24H_E09_dexamethasone_0.12uM.tsv',
#    'local_id': 'LKCP002_A549_24H_E09_dexamethasone_0.12uM',
#    'cell_line': 'A549',
#    'pert_dose': '0.12 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-19',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_LKCP002_A549_24H_E09_dexamethasone_0.12uM.tsv',
#    'size_in_bytes': 216954,
#    'uncompressed_size_in_bytes': 216954}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': 'c6befb05-6ba3-5511-ae95-e68d5d965819',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '856e2b933a592a11f06656c8124db0f1',
#    'doid': 'DOID:1324',
#    'sha256': '0f6bd1aa51d9860a9fc98cd992e62bfef8ef4d77f8fcc1247545a2e90e686455',
#    'tissue': 'lung',
#    'anatomy': 'UBERON:0002048',
#    'cmap_id': 'LKCP002_A549_6H:E08',
#    'disease': 'lung cancer',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_LKCP002_A549_6H_E08_dexamethasone_1.11uM.tsv',
#    'local_id': 'LKCP002_A549_6H_E08_dexamethasone_1.11uM',
#    'cell_line': 'A549',
#    'pert_dose': '1.11 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '6 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-19',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_LKCP002_A549_6H_E08_dexamethasone_1.11uM.tsv',
#    'size_in_bytes': 216855,
#    'uncompressed_size_in_bytes': 216855}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '4a6a4d63-619f-5bb1-848e-e729e15a9c9e',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '75a4f0e2d5e0450dc783f9f45b705205',
#    'doid': 'DOID:1324',
#    'sha256': '4c5fc3fba7c231879a8e657418967b732b81ddf11b9a78cf9341f4bc7bf1efb8',
#    'tissue': 'lung',
#    'anatomy': 'UBERON:0002048',
#    'cmap_id': 'CPC014_A549_6H:BRD-K38775274-001-13-0:10',
#    'disease': 'lung cancer',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC014_A549_6H_H21_dexamethasone_10uM.tsv',
#    'local_id': 'CPC014_A549_6H_H21_dexamethasone_10uM',
#    'cell_line': 'A549',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '6 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-14',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC014_A549_6H_H21_dexamethasone_10uM.tsv',
#    'size_in_bytes': 216973,
#    'uncompressed_size_in_bytes': 216973}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '0ec33d98-8a60-5df8-b011-754671b80d21',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': 'c3dd7e0581fa119a09bfa554042b3e63',
#    'doid': 'DOID:2526',
#    'sha256': '94687c7ac58b88472b1fbcbcef8d397a008c11aa3e71e11f5bb6958293d06854',
#    'tissue': 'prostate gland',
#    'anatomy': 'UBERON:0002367',
#    'cmap_id': 'CPC014_PC3_24H:BRD-K38775274-001-13-0:10',
#    'disease': 'prostate adenocarcinoma',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC014_PC3_24H_H21_dexamethasone_10uM.tsv',
#    'local_id': 'CPC014_PC3_24H_H21_dexamethasone_10uM',
#    'cell_line': 'PC3',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-14',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC014_PC3_24H_H21_dexamethasone_10uM.tsv',
#    'size_in_bytes': 217264,
#    'uncompressed_size_in_bytes': 217264}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '2702eea8-91fb-51af-b4f5-58cdd7fdacb6',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '1bd39b863d34718d31b10329baf567cd',
#    'doid': 'DOID:2526',
#    'sha256': '8a4c38a4df07ac0ccc956b775744b6a9d34559cf63d88fb2c68609e8f2d6d5bc',
#    'tissue': 'prostate gland',
#    'anatomy': 'UBERON:0002367',
#    'cmap_id': 'CPC014_VCAP_24H:BRD-K38775274-001-13-0:10',
#    'disease': 'prostate adenocarcinoma',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC014_VCAP_24H_H21_dexamethasone_10uM.tsv',
#    'local_id': 'CPC014_VCAP_24H_H21_dexamethasone_10uM',
#    'cell_line': 'VCAP',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-14',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC014_VCAP_24H_H21_dexamethasone_10uM.tsv',
#    'size_in_bytes': 217114,
#    'uncompressed_size_in_bytes': 217114}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '0e697533-ab6b-5bca-82ff-2e008018d719',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '6fb7c728bcef3d24585938349b7a95b9',
#    'doid': 'DOID:1520',
#    'sha256': 'a4f94311d87634c9747ee15032bc9cf4a3a260cdeae2a9fa27c16fd86c247078',
#    'tissue': 'intestine',
#    'anatomy': 'UBERON:0000160',
#    'cmap_id': 'CPC014_HT29_6H:BRD-K38775274-001-13-0:10',
#    'disease': 'colon adenocarcinoma',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC014_HT29_6H_H21_dexamethasone_10uM.tsv',
#    'local_id': 'CPC014_HT29_6H_H21_dexamethasone_10uM',
#    'cell_line': 'HT29',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '6 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-14',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC014_HT29_6H_H21_dexamethasone_10uM.tsv',
#    'size_in_bytes': 217236,
#    'uncompressed_size_in_bytes': 217236}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '1ba1e337-b247-570c-95f9-27305718925d',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '0b4e8c7db85c344d3832b63959593237',
#    'doid': 'DOID:1909',
#    'sha256': '8c88942ece69cd17aacb8cbb34eddfd2208c23c1530920e0088a29d8d0899bfd',
#    'tissue': 'skin of body',
#    'anatomy': 'UBERON:0002097',
#    'cmap_id': 'CPC014_A375_6H:H21',
#    'disease': 'melanoma',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC014_A375_6H_H21_dexamethasone_10uM.tsv',
#    'local_id': 'CPC014_A375_6H_H21_dexamethasone_10uM',
#    'cell_line': 'A375',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '6 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-14',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC014_A375_6H_H21_dexamethasone_10uM.tsv',
#    'size_in_bytes': 216897,
#    'uncompressed_size_in_bytes': 216897}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '42901e0f-8e8f-5baa-99fa-69d06c9bcdd3',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': 'a421a8c7ff4e79b46e7030fc2671eed0',
#    'sha256': 'bc95bf62a19f7709efa035e08ce94805487a8fe4c1e60e0707c6667b75f52101',
#    'tissue': 'liver',
#    'anatomy': 'UBERON:0002107',
#    'cmap_id': 'CPC014_PHH_24H:BRD-K38775274-001-13-0:10',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC014_PHH_24H_H21_dexamethasone_10uM.tsv',
#    'local_id': 'CPC014_PHH_24H_H21_dexamethasone_10uM',
#    'cell_line': 'PHH',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-14',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC014_PHH_24H_H21_dexamethasone_10uM.tsv',
#    'size_in_bytes': 217130,
#    'uncompressed_size_in_bytes': 217130}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': 'a03ee89a-9567-57b9-be4f-c68a9c044e39',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': 'a13aa3c57b2c9ae70057a8643e1b4e09',
#    'doid': 'DOID:1324',
#    'sha256': '3bde0492b50b726f4e95ba36d8223474cd11582522e4b9a1a1f179be357d40df',
#    'tissue': 'lung',
#    'anatomy': 'UBERON:0002048',
#    'cmap_id': 'CPC014_HCC515_6H:BRD-K38775274-001-13-0:10',
#    'disease': 'lung cancer',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC014_HCC515_6H_H21_dexamethasone_10uM.tsv',
#    'local_id': 'CPC014_HCC515_6H_H21_dexamethasone_10uM',
#    'cell_line': 'HCC515',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '6 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-14',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC014_HCC515_6H_H21_dexamethasone_10uM.tsv',
#    'size_in_bytes': 217140,
#    'uncompressed_size_in_bytes': 217140}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '98783c36-6f72-518c-ade3-5101af135bfe',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '6e7df31e5c04bf96dba65dceea179112',
#    'sha256': '815ca5900e61d8aabc7f00d0730ad5e1af6276212279e6493365d126d904cb82',
#    'tissue': 'central nervous system',
#    'anatomy': 'UBERON:0001017',
#    'cmap_id': 'CPC014_NEU_24H:BRD-K38775274-001-13-0:10',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC014_NEU_24H_H21_dexamethasone_10uM.tsv',
#    'local_id': 'CPC014_NEU_24H_H21_dexamethasone_10uM',
#    'cell_line': 'NEU',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-14',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC014_NEU_24H_H21_dexamethasone_10uM.tsv',
#    'size_in_bytes': 217262,
#    'uncompressed_size_in_bytes': 217262}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '9c3f9cd3-9a1a-5da1-9160-f524eb62d869',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': 'a94d015e4125e0725691abc7764a2406',
#    'doid': 'DOID:2526',
#    'sha256': '4cc2521065f545c6fffb7f371c55358f20e546ec31471617e5b19f8b7a7f8c89',
#    'tissue': 'prostate gland',
#    'anatomy': 'UBERON:0002367',
#    'cmap_id': 'CPC014_PC3_6H:BRD-K38775274-001-13-0:10',
#    'disease': 'prostate adenocarcinoma',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC014_PC3_6H_H21_dexamethasone_10uM.tsv',
#    'local_id': 'CPC014_PC3_6H_H21_dexamethasone_10uM',
#    'cell_line': 'PC3',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '6 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-14',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC014_PC3_6H_H21_dexamethasone_10uM.tsv',
#    'size_in_bytes': 217316,
#    'uncompressed_size_in_bytes': 217316}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '77ed79f3-64e4-58b9-bde5-c4698172fd3e',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': 'e682a40ed769e8260a235935ae90836c',
#    'doid': 'DOID:1324',
#    'sha256': '7d977b5b3294c9c8b0470d61edfff0fbab98858dfb7014519d708eb321d8cc25',
#    'tissue': 'lung',
#    'anatomy': 'UBERON:0002048',
#    'cmap_id': 'CPC014_A549_24H:BRD-K38775274-001-13-0:10',
#    'disease': 'lung cancer',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC014_A549_24H_H21_dexamethasone_10uM.tsv',
#    'local_id': 'CPC014_A549_24H_H21_dexamethasone_10uM',
#    'cell_line': 'A549',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-14',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC014_A549_24H_H21_dexamethasone_10uM.tsv',
#    'size_in_bytes': 216906,
#    'uncompressed_size_in_bytes': 216906}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '7b48bc15-34e7-5a0f-aec7-96f2e8abc50e',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': 'fc2561598761c1359273e1af791d26b5',
#    'doid': 'DOID:3459',
#    'sha256': '2ac9f7cedad09992393d83ada1222d449942c14ac09baa31b3a5c0d6d145325a',
#    'tissue': 'breast',
#    'anatomy': 'UBERON:0000310',
#    'cmap_id': 'CPC014_MCF7_24H:BRD-K38775274-001-13-0:10',
#    'disease': 'breast adenocarcinoma',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC014_MCF7_24H_H21_dexamethasone_10uM.tsv',
#    'local_id': 'CPC014_MCF7_24H_H21_dexamethasone_10uM',
#    'cell_line': 'MCF7',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-14',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC014_MCF7_24H_H21_dexamethasone_10uM.tsv',
#    'size_in_bytes': 217177,
#    'uncompressed_size_in_bytes': 217177}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '7f5f24e5-88bf-5682-9df0-61f64ebfb700',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': 'a1997ab410b487b1bed4cb51f08c8c2e',
#    'sha256': '6900604f9a9acac824e7db255da9d250e01acd893cb6a43b62ee0ecb18383f16',
#    'tissue': 'skeletal muscle organ',
#    'anatomy': 'UBERON:0014892',
#    'cmap_id': 'CPC014_SKB_24H:BRD-K38775274-001-13-0:10',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC014_SKB_24H_H21_dexamethasone_10uM.tsv',
#    'local_id': 'CPC014_SKB_24H_H21_dexamethasone_10uM',
#    'cell_line': 'SKB',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-14',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC014_SKB_24H_H21_dexamethasone_10uM.tsv',
#    'size_in_bytes': 217330,
#    'uncompressed_size_in_bytes': 217330}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '921acef2-de57-5d31-a89c-da2751d23f97',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '85f00730dca812ee3549b53c51b0a263',
#    'sha256': '7efb3020305e282f5f8d916330cdf9fe443e8cd67692aa1424dd9b04ba131ac4',
#    'tissue': 'kidney',
#    'anatomy': 'UBERON:0002113',
#    'cmap_id': 'CPC014_HA1E_6H:BRD-K38775274-001-13-0:10',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC014_HA1E_6H_H21_dexamethasone_10uM.tsv',
#    'local_id': 'CPC014_HA1E_6H_H21_dexamethasone_10uM',
#    'cell_line': 'HA1E',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '6 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-14',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC014_HA1E_6H_H21_dexamethasone_10uM.tsv',
#    'size_in_bytes': 217199,
#    'uncompressed_size_in_bytes': 217199}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': 'cf2834ab-751e-56e8-bed3-fa9ae8da495b',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '2dc9133447c332c31114d3c849b874fb',
#    'doid': 'DOID:305',
#    'sha256': 'f6709b379caefd7198bcf3eb1f7edb844c566328c5d27ac62321d9ac3b01fd93',
#    'tissue': 'liver',
#    'anatomy': 'UBERON:0002107',
#    'cmap_id': 'CPC014_HEPG2_6H:BRD-K38775274-001-13-0:10',
#    'disease': 'carcinoma',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC014_HEPG2_6H_H21_dexamethasone_10uM.tsv',
#    'local_id': 'CPC014_HEPG2_6H_H21_dexamethasone_10uM',
#    'cell_line': 'HEPG2',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '6 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-14',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC014_HEPG2_6H_H21_dexamethasone_10uM.tsv',
#    'size_in_bytes': 217073,
#    'uncompressed_size_in_bytes': 217073}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': 'bd309d62-cbde-5b28-8e9a-2ae4d982ab5f',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '931820aac6bdbed787f630141a8cf1b4',
#    'sha256': '7cea06a198a2ff5ccbda091a87d1d2cc27074dfe37bd8c2ebc935bef19c40ba9',
#    'tissue': 'adipose tissue',
#    'anatomy': 'UBERON:0001013',
#    'cmap_id': 'CPC014_ASC_24H:BRD-K38775274-001-13-0:10',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC014_ASC_24H_H21_dexamethasone_10uM.tsv',
#    'local_id': 'CPC014_ASC_24H_H21_dexamethasone_10uM',
#    'cell_line': 'ASC',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-14',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC014_ASC_24H_H21_dexamethasone_10uM.tsv',
#    'size_in_bytes': 217006,
#    'uncompressed_size_in_bytes': 217006}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': 'a6dbc3b5-03ea-5cba-9a46-0608d84a1f1c',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '01a8c83ac7521ad175ceb13c4bffefc8',
#    'sha256': '1c6e25477d507f4e7f9480e2d59113a45c89cdf1d820552147d3f1025768f2f4',
#    'tissue': 'connective tissue',
#    'anatomy': 'UBERON:0002384',
#    'cmap_id': 'CPC014_NPC_24H:BRD-K38775274-001-13-0:10',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC014_NPC_24H_H21_dexamethasone_10uM.tsv',
#    'local_id': 'CPC014_NPC_24H_H21_dexamethasone_10uM',
#    'cell_line': 'NPC',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-14',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC014_NPC_24H_H21_dexamethasone_10uM.tsv',
#    'size_in_bytes': 217060,
#    'uncompressed_size_in_bytes': 217060}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': 'ce18b40e-e27f-51fd-927a-1e3101e34860',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '4da014dc12a987a06451e800299596fa',
#    'doid': 'DOID:3459',
#    'sha256': 'c5bd55247130285d9487d208a1721aec15d03714b49c94aed8452c6310cab76a',
#    'tissue': 'breast',
#    'anatomy': 'UBERON:0000310',
#    'cmap_id': 'CPC014_MCF7_6H:H21',
#    'disease': 'breast adenocarcinoma',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC014_MCF7_6H_H21_dexamethasone_10uM.tsv',
#    'local_id': 'CPC014_MCF7_6H_H21_dexamethasone_10uM',
#    'cell_line': 'MCF7',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '6 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-14',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC014_MCF7_6H_H21_dexamethasone_10uM.tsv',
#    'size_in_bytes': 217537,
#    'uncompressed_size_in_bytes': 217537}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '12adea0c-0956-5092-9407-ebb903d2a256',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': 'a955086c6e1c1991d8083cccaa0511c6',
#    'doid': 'DOID:3702',
#    'sha256': '5e1fef388d1f3fd7f6edc1c0f319810cb2e312e113a2298fa8696cf19149cfd1',
#    'tissue': 'uterine cervix',
#    'anatomy': 'UBERON:0000002',
#    'cmap_id': 'REP.A016_HELA_24H:N01',
#    'disease': 'cervical adenocarcinoma',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_REP.A016_HELA_24H_N01_dexamethasone_10uM.tsv',
#    'local_id': 'REP.A016_HELA_24H_N01_dexamethasone_10uM',
#    'cell_line': 'HELA',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-22',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_REP.A016_HELA_24H_N01_dexamethasone_10uM.tsv',
#    'size_in_bytes': 217480,
#    'uncompressed_size_in_bytes': 217480}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '057632b9-b159-59a4-847d-53a911b6bda4',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': 'cdd71c1f12c7e3d46856240ba5855a6f',
#    'doid': 'DOID:3459',
#    'sha256': '7dcc1afe6cf22317cd36eda21f632f53a987e8cf7b43d00016e5c36771854927',
#    'tissue': 'breast',
#    'anatomy': 'UBERON:0000310',
#    'cmap_id': 'REP.A016_MCF7_24H:N04',
#    'disease': 'breast adenocarcinoma',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_REP.A016_MCF7_24H_N04_dexamethasone_0.37uM.tsv',
#    'local_id': 'REP.A016_MCF7_24H_N04_dexamethasone_0.37uM',
#    'cell_line': 'MCF7',
#    'pert_dose': '0.37 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-22',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_REP.A016_MCF7_24H_N04_dexamethasone_0.37uM.tsv',
#    'size_in_bytes': 216902,
#    'uncompressed_size_in_bytes': 216902}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '0f34a013-41e5-5d11-96ab-b8d630d4107e',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': 'fa37b1ddac96f1ee8dd2fb9247c55a9f',
#    'doid': 'DOID:3459',
#    'sha256': 'f9c73b34d515f82ddd0b1e92fcf470a944a5eb873e467c1baecb0c5ff0035f40',
#    'tissue': 'breast',
#    'anatomy': 'UBERON:0000310',
#    'cmap_id': 'REP.A016_MCF7_24H:N06',
#    'disease': 'breast adenocarcinoma',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_REP.A016_MCF7_24H_N06_dexamethasone_0.04uM.tsv',
#    'local_id': 'REP.A016_MCF7_24H_N06_dexamethasone_0.04uM',
#    'cell_line': 'MCF7',
#    'pert_dose': '0.04 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-22',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_REP.A016_MCF7_24H_N06_dexamethasone_0.04uM.tsv',
#    'size_in_bytes': 217092,
#    'uncompressed_size_in_bytes': 217092}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '0c6d7e90-b01f-5df4-a8b9-a0e720111a97',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': 'b82140f6f1e37c9c0dd7e223c7e4b43f',
#    'doid': 'DOID:1909',
#    'sha256': '6ffbcc4fc1ea502282e0a285bac312805ee7dd4892369531255f48e8b50673d2',
#    'tissue': 'skin of body',
#    'anatomy': 'UBERON:0002097',
#    'cmap_id': 'REP.A016_A375_24H:N04',
#    'disease': 'melanoma',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_REP.A016_A375_24H_N04_dexamethasone_0.37uM.tsv',
#    'local_id': 'REP.A016_A375_24H_N04_dexamethasone_0.37uM',
#    'cell_line': 'A375',
#    'pert_dose': '0.37 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-22',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_REP.A016_A375_24H_N04_dexamethasone_0.37uM.tsv',
#    'size_in_bytes': 217242,
#    'uncompressed_size_in_bytes': 217242}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '20b27b32-4898-5338-904e-6b12f8ff3ff6',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '9d6cbd3b0b73c4d48b1d00085ecd4fb4',
#    'sha256': '6382c4dd20b1dd329fc27c5887e698cc6d268053c04cfdd6bf13b54a42f83085',
#    'tissue': 'kidney',
#    'anatomy': 'UBERON:0002113',
#    'cmap_id': 'REP.A016_HEK293_24H:N06',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_REP.A016_HEK293_24H_N06_dexamethasone_0.04uM.tsv',
#    'local_id': 'REP.A016_HEK293_24H_N06_dexamethasone_0.04uM',
#    'cell_line': 'HEK293',
#    'pert_dose': '0.04 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-22',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_REP.A016_HEK293_24H_N06_dexamethasone_0.04uM.tsv',
#    'size_in_bytes': 217373,
#    'uncompressed_size_in_bytes': 217373}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '1726ecb9-678c-5d56-a58f-24658162facd',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': 'a8fd8d3925db6b03b740ffac88ece0bc',
#    'doid': 'DOID:3459',
#    'sha256': '6bc7ac9034dfd6f225d46b2605fdccc2e0e96e14cab56d03f6a1d601913997cc',
#    'tissue': 'breast',
#    'anatomy': 'UBERON:0000310',
#    'cmap_id': 'REP.A016_MDAMB231_24H:N06',
#    'disease': 'breast adenocarcinoma',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_REP.A016_MDAMB231_24H_N06_dexamethasone_0.04uM.tsv',
#    'local_id': 'REP.A016_MDAMB231_24H_N06_dexamethasone_0.04uM',
#    'cell_line': 'MDAMB231',
#    'pert_dose': '0.04 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-22',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_REP.A016_MDAMB231_24H_N06_dexamethasone_0.04uM.tsv',
#    'size_in_bytes': 216794,
#    'uncompressed_size_in_bytes': 216794}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '2d7003bd-7fc1-5e04-8c08-c2ec40c03b2a',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '94e9829daaeabe74a9e0489434985c4a',
#    'doid': 'DOID:1324',
#    'sha256': 'c2b36b97907c79de6cb9e22d550384e4f7c0abae124e7c1bbe1d30f570a9e854',
#    'tissue': 'lung',
#    'anatomy': 'UBERON:0002048',
#    'cmap_id': 'CPC015_A549_24H:BRD-K47635719-001-03-9:10',
#    'disease': 'lung cancer',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC015_A549_24H_C04_dexamethasone_10uM.tsv',
#    'local_id': 'CPC015_A549_24H_C04_dexamethasone_10uM',
#    'cell_line': 'A549',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-15',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC015_A549_24H_C04_dexamethasone_10uM.tsv',
#    'size_in_bytes': 217076,
#    'uncompressed_size_in_bytes': 217076}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '2b5fcddd-adab-54bb-aea0-ce17c8553cef',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '2de56dd37e571d70679d75dbde7eaf5f',
#    'doid': 'DOID:1324',
#    'sha256': '336568c12ae442ec66498cc5db2d3f5046aec771514868d0f9930846eafe13ed',
#    'tissue': 'lung',
#    'anatomy': 'UBERON:0002048',
#    'cmap_id': 'REP.A016_A549_24H:N06',
#    'disease': 'lung cancer',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_REP.A016_A549_24H_N06_dexamethasone_0.04uM.tsv',
#    'local_id': 'REP.A016_A549_24H_N06_dexamethasone_0.04uM',
#    'cell_line': 'A549',
#    'pert_dose': '0.04 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-22',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_REP.A016_A549_24H_N06_dexamethasone_0.04uM.tsv',
#    'size_in_bytes': 217487,
#    'uncompressed_size_in_bytes': 217487}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '2d258e8d-71de-51a1-9b81-982e54d552d8',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '8b1035feceed70b8a7d7f4ef9cea159e',
#    'doid': 'DOID:305',
#    'sha256': '94a4618bdccaef12d21939fe78f5e2bc21d90ce7ceb2fe665de348952a815ceb',
#    'tissue': 'liver',
#    'anatomy': 'UBERON:0002107',
#    'cmap_id': 'CPC015_HEPG2_6H:BRD-K47635719-001-03-9:10',
#    'disease': 'carcinoma',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC015_HEPG2_6H_C04_dexamethasone_10uM.tsv',
#    'local_id': 'CPC015_HEPG2_6H_C04_dexamethasone_10uM',
#    'cell_line': 'HEPG2',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '6 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-15',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC015_HEPG2_6H_C04_dexamethasone_10uM.tsv',
#    'size_in_bytes': 217428,
#    'uncompressed_size_in_bytes': 217428}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '44356f45-26f3-595b-bcd8-9a8f9c7590b5',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': 'e7b1fe1c9e389c49cbf91316bf72d947',
#    'doid': 'DOID:3459',
#    'sha256': '49b8427d65b579f5c74b6b3beaf600ced42579b5b6090d9a2e4fc5c53bda7008',
#    'tissue': 'breast',
#    'anatomy': 'UBERON:0000310',
#    'cmap_id': 'REP.A016_MCF7_24H:N01',
#    'disease': 'breast adenocarcinoma',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_REP.A016_MCF7_24H_N01_dexamethasone_10uM.tsv',
#    'local_id': 'REP.A016_MCF7_24H_N01_dexamethasone_10uM',
#    'cell_line': 'MCF7',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-22',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_REP.A016_MCF7_24H_N01_dexamethasone_10uM.tsv',
#    'size_in_bytes': 217240,
#    'uncompressed_size_in_bytes': 217240}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '2f1c5bb1-78b4-5a40-bb15-5972126bee2d',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '6ba16f782823e49bb800f2e8734a583c',
#    'sha256': '0752c092e129d3b3cd42faa8873214b7d06932f7914805d0cfe9b327d6ef6b4b',
#    'tissue': 'kidney',
#    'anatomy': 'UBERON:0002113',
#    'cmap_id': 'REP.A016_HEK293_24H:N05',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_REP.A016_HEK293_24H_N05_dexamethasone_0.125uM.tsv',
#    'local_id': 'REP.A016_HEK293_24H_N05_dexamethasone_0.125uM',
#    'cell_line': 'HEK293',
#    'pert_dose': '0.125 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-22',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_REP.A016_HEK293_24H_N05_dexamethasone_0.125uM.tsv',
#    'size_in_bytes': 217398,
#    'uncompressed_size_in_bytes': 217398}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '41f58368-8f44-5ab4-a653-1a71925eb52e',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '5407aa37e7b5d18dd688a82d3c5da1be',
#    'doid': 'DOID:1240',
#    'sha256': '62b811bd10cffd3354573ecbcfc0c0ca9878555aebdb8fce6d617b185b7ea176',
#    'tissue': 'blood',
#    'anatomy': 'UBERON:0000178',
#    'cmap_id': 'REP.A016_JURKAT_24H:N01',
#    'disease': 'leukemia',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_REP.A016_JURKAT_24H_N01_dexamethasone_10uM.tsv',
#    'local_id': 'REP.A016_JURKAT_24H_N01_dexamethasone_10uM',
#    'cell_line': 'JURKAT',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-22',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_REP.A016_JURKAT_24H_N01_dexamethasone_10uM.tsv',
#    'size_in_bytes': 217231,
#    'uncompressed_size_in_bytes': 217231}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '4815fa65-da55-52c3-bff7-a41628b0aa34',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': 'a2f16ab457526a7bf8a9a931281a204d',
#    'sha256': 'cfa4247aadd66d7f0e64dc42372de0cc9fdc913acec472eacbc9a98bba2a83af',
#    'tissue': 'kidney',
#    'anatomy': 'UBERON:0002113',
#    'cmap_id': 'REP.A016_HA1E_24H:N01',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_REP.A016_HA1E_24H_N01_dexamethasone_10uM.tsv',
#    'local_id': 'REP.A016_HA1E_24H_N01_dexamethasone_10uM',
#    'cell_line': 'HA1E',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-22',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_REP.A016_HA1E_24H_N01_dexamethasone_10uM.tsv',
#    'size_in_bytes': 217192,
#    'uncompressed_size_in_bytes': 217192}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '944dc415-40c5-5df1-be81-3ef7ef8baddd',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '9a4337eef57572b0b48b9e2d696dfddb',
#    'doid': 'DOID:3702',
#    'sha256': '93310a2a97580cf9886ebe61b913e2a15c3564e6239bb6ddd240ac26266313b1',
#    'tissue': 'uterine cervix',
#    'anatomy': 'UBERON:0000002',
#    'cmap_id': 'REP.A016_HELA_24H:N05',
#    'disease': 'cervical adenocarcinoma',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_REP.A016_HELA_24H_N05_dexamethasone_0.125uM.tsv',
#    'local_id': 'REP.A016_HELA_24H_N05_dexamethasone_0.125uM',
#    'cell_line': 'HELA',
#    'pert_dose': '0.125 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-22',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_REP.A016_HELA_24H_N05_dexamethasone_0.125uM.tsv',
#    'size_in_bytes': 217419,
#    'uncompressed_size_in_bytes': 217419}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '4bd9de33-1d76-5aa3-b320-3409ce5954c5',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '9d93d94ce906fe41a750f41ed081843a',
#    'doid': 'DOID:3459',
#    'sha256': '17c82497c953784fa71e5503692dabc55a299ee018f58740663cf7a48b58ae2a',
#    'tissue': 'breast',
#    'anatomy': 'UBERON:0000310',
#    'cmap_id': 'REP.A016_MDAMB231_24H:N02',
#    'disease': 'breast adenocarcinoma',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_REP.A016_MDAMB231_24H_N02_dexamethasone_3.33uM.tsv',
#    'local_id': 'REP.A016_MDAMB231_24H_N02_dexamethasone_3.33uM',
#    'cell_line': 'MDAMB231',
#    'pert_dose': '3.33 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-22',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_REP.A016_MDAMB231_24H_N02_dexamethasone_3.33uM.tsv',
#    'size_in_bytes': 217186,
#    'uncompressed_size_in_bytes': 217186}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '4de9f05d-3157-5f64-a6f9-e6cc93787e53',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '760da3122b7fc17ace682a94d4b91a05',
#    'doid': 'DOID:1324',
#    'sha256': 'f23394565b127aabb6d0604bd180d7404444dba679d59e80e839e2fc52d08a1e',
#    'tissue': 'lung',
#    'anatomy': 'UBERON:0002048',
#    'cmap_id': 'REP.A016_A549_24H:N02',
#    'disease': 'lung cancer',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_REP.A016_A549_24H_N02_dexamethasone_3.33uM.tsv',
#    'local_id': 'REP.A016_A549_24H_N02_dexamethasone_3.33uM',
#    'cell_line': 'A549',
#    'pert_dose': '3.33 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
# ...
#    'tissue': 'ovary',
#    'anatomy': 'UBERON:0000992',
#    'cmap_id': 'CPC006_EFO27_6H:BRD-A69951442-001-01-3:10',
#    'disease': 'ovarian carcinoma',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC006_EFO27_6H_O03_dexamethasone_10uM.tsv',
#    'local_id': 'CPC006_EFO27_6H_O03_dexamethasone_10uM',
#    'cell_line': 'EFO27',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '6 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-08',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC006_EFO27_6H_O03_dexamethasone_10uM.tsv',
#    'size_in_bytes': 345295,
#    'uncompressed_size_in_bytes': 345295}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': 'ccf076e7-6968-5173-b762-6df34c124677',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': 'fa6f35eda4306f6fb0a7cc6efdbbf849',
#    'doid': 'DOID:3247',
#    'sha256': 'e6904623d36a970eda7c47392545481df1db0cb0424f398986c7ea0f39215988',
#    'tissue': 'muscle organ',
#    'anatomy': 'UBERON:0001630',
#    'cmap_id': 'CPC006_A673_6H:BRD-A69951442-001-01-3:10',
#    'disease': "ewing's sarcoma",
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC006_A673_6H_O03_dexamethasone_10uM.tsv',
#    'local_id': 'CPC006_A673_6H_O03_dexamethasone_10uM',
#    'cell_line': 'A673',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '6 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-08',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC006_A673_6H_O03_dexamethasone_10uM.tsv',
#    'size_in_bytes': 345692,
#    'uncompressed_size_in_bytes': 345692}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '743349b8-21b6-5cab-ae39-0aecc5c22672',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '5d3f07c26703dc53ce18b5002706bbe5',
#    'doid': 'DOID:1324',
#    'sha256': 'f6189b3e2cebea47e291da7b5da6a67ba161792c3bebdd5305bfa839591ffda0',
#    'tissue': 'lung',
#    'anatomy': 'UBERON:0002048',
#    'cmap_id': 'CPC006_H1299_6H:BRD-A35108200-001-04-7:10',
#    'disease': 'lung cancer',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC006_H1299_6H_F09_dexamethasone_10uM.tsv',
#    'local_id': 'CPC006_H1299_6H_F09_dexamethasone_10uM',
#    'cell_line': 'H1299',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '6 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-08',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC006_H1299_6H_F09_dexamethasone_10uM.tsv',
#    'size_in_bytes': 345075,
#    'uncompressed_size_in_bytes': 345075}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '87e18ac2-8875-5dcf-a741-41f962802a94',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '080047d45d6031938590957057bce2cb',
#    'doid': 'DOID:1520',
#    'sha256': '75008a958bb4b5a3cf99d42bb05b6be958b1a753b8447b8d39f0a04a353ca574',
#    'tissue': 'large intestine',
#    'anatomy': 'UBERON:0000059',
#    'cmap_id': 'CPC006_CL34_6H:BRD-A69951442-001-01-3:10',
#    'disease': 'colon adenocarcinoma',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC006_CL34_6H_O03_dexamethasone_10uM.tsv',
#    'local_id': 'CPC006_CL34_6H_O03_dexamethasone_10uM',
#    'cell_line': 'CL34',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '6 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-08',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC006_CL34_6H_O03_dexamethasone_10uM.tsv',
#    'size_in_bytes': 345405,
#    'uncompressed_size_in_bytes': 345405}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': '97ef7f7f-6873-5669-80db-092471f4cd2d',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '113ad1d4b28d1aad0114d5b582c2d7cf',
#    'doid': 'DOID:1324',
#    'sha256': 'f3e21111dd9f25eb34b52e71858253b6b9df8311836a26a4aeaf1b8cebd23d62',
#    'tissue': 'lung',
#    'anatomy': 'UBERON:0002048',
#    'cmap_id': 'CPC006_A549_6H:BRD-A35108200-001-04-7:10',
#    'disease': 'lung cancer',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC006_A549_6H_F09_dexamethasone_10uM.tsv',
#    'local_id': 'CPC006_A549_6H_F09_dexamethasone_10uM',
#    'cell_line': 'A549',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '6 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-08',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC006_A549_6H_F09_dexamethasone_10uM.tsv',
#    'size_in_bytes': 345656,
#    'uncompressed_size_in_bytes': 345656}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': 'c334bd60-058f-56a5-85dd-e2281549dc9b',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '13e33933f6d2556e0fb5c0665b16926c',
#    'doid': 'DOID:1909',
#    'sha256': 'f1834d49ca4736640610cee35e79a53d81c1296ab12aaaef57501351cbe9aeef',
#    'tissue': 'skin of body',
#    'anatomy': 'UBERON:0002097',
#    'cmap_id': 'CPC006_A375_24H:BRD-A35108200-001-04-7:10',
#    'disease': 'melanoma',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC006_A375_24H_F09_dexamethasone_10uM.tsv',
#    'local_id': 'CPC006_A375_24H_F09_dexamethasone_10uM',
#    'cell_line': 'A375',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-07',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC006_A375_24H_F09_dexamethasone_10uM.tsv',
#    'size_in_bytes': 345327,
#    'uncompressed_size_in_bytes': 345327}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': 'c34a9f30-58e1-5894-a24d-730812fdcfea',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '816efa4eddc44342a878c6d1d992b28c',
#    'doid': 'DOID:1324',
#    'sha256': '4815513d6466d136e1a7057f7aea00029fb01e68f45272a3e0f8e3913926975d',
#    'tissue': 'lung',
#    'anatomy': 'UBERON:0002048',
#    'cmap_id': 'CPC006_A549_24H:BRD-A69951442-001-01-3:10',
#    'disease': 'lung cancer',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC006_A549_24H_O03_dexamethasone_10uM.tsv',
#    'local_id': 'CPC006_A549_24H_O03_dexamethasone_10uM',
#    'cell_line': 'A549',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-08',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC006_A549_24H_O03_dexamethasone_10uM.tsv',
#    'size_in_bytes': 345545,
#    'uncompressed_size_in_bytes': 345545}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': 'df653afd-bf1a-5450-a6b3-42c033af2db9',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': 'ed389d659e012875aa90cc7f5b17b6bc',
#    'doid': 'DOID:1909',
#    'sha256': '1b3f91062a82df908e62c41a8ce0c21242308db6f9ab749eb0bde5b45b4871ed',
#    'tissue': 'skin of body',
#    'anatomy': 'UBERON:0002097',
#    'cmap_id': 'CPC006_A375_6H:O03',
#    'disease': 'melanoma',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC006_A375_6H_O03_dexamethasone_10uM.tsv',
#    'local_id': 'CPC006_A375_6H_O03_dexamethasone_10uM',
#    'cell_line': 'A375',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '6 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-08',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC006_A375_6H_O03_dexamethasone_10uM.tsv',
#    'size_in_bytes': 345339,
#    'uncompressed_size_in_bytes': 345339}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': 'd92be113-b888-5155-9e24-9e3744164a25',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': 'e896d609eeca3a792d81e2998695a22c',
#    'doid': 'DOID:1909',
#    'sha256': 'cbe411122485ddba3774ed98752b23130a5a2e5ca796af7a5e28b137618e36fd',
#    'tissue': 'skin of body',
#    'anatomy': 'UBERON:0002097',
#    'cmap_id': 'CPC006_A375_24H:BRD-A69951442-001-01-3:10',
#    'disease': 'melanoma',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC006_A375_24H_O03_dexamethasone_10uM.tsv',
#    'local_id': 'CPC006_A375_24H_O03_dexamethasone_10uM',
#    'cell_line': 'A375',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '24 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-07',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC006_A375_24H_O03_dexamethasone_10uM.tsv',
#    'size_in_bytes': 345389,
#    'uncompressed_size_in_bytes': 345389}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': 'e4d020ec-170a-55d8-8432-501da49c6cf9',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '8cbd9e21980dd5fcb4adb3c9dc6f453e',
#    'doid': 'DOID:4001',
#    'sha256': 'bc95abbbb41476e463233b53d751f2287585c1010bbfbfb1d1f0fb95e4b85acc',
#    'tissue': 'ovary',
#    'anatomy': 'UBERON:0000992',
#    'cmap_id': 'CPC006_EFO27_6H:BRD-A35108200-001-04-7:10',
#    'disease': 'ovarian carcinoma',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC006_EFO27_6H_F09_dexamethasone_10uM.tsv',
#    'local_id': 'CPC006_EFO27_6H_F09_dexamethasone_10uM',
#    'cell_line': 'EFO27',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '6 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-08',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC006_EFO27_6H_F09_dexamethasone_10uM.tsv',
#    'size_in_bytes': 345103,
#    'uncompressed_size_in_bytes': 345103}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': 'e38c7cc9-7ad2-58d3-92d5-66211465ef1e',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '1e7732b55c746e622276ef9b57c90442',
#    'doid': 'DOID:1324',
#    'sha256': 'ad65aafb2d7bb4d93efa47c60d708ab18ea4f05d6bdf1fd18c4fe1ac6ea93a3f',
#    'tissue': 'lung',
#    'anatomy': 'UBERON:0002048',
#    'cmap_id': 'CPC006_DV90_6H:BRD-A69951442-001-01-3:10',
#    'disease': 'lung cancer',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC006_DV90_6H_O03_dexamethasone_10uM.tsv',
#    'local_id': 'CPC006_DV90_6H_O03_dexamethasone_10uM',
#    'cell_line': 'DV90',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '6 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-08',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC006_DV90_6H_O03_dexamethasone_10uM.tsv',
#    'size_in_bytes': 345162,
#    'uncompressed_size_in_bytes': 345162}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': 'eae1368d-c17a-5227-a94f-23a917b14256',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '61480526868312cd2af17d580986193b',
#    'doid': 'DOID:1324',
#    'sha256': '829cdeb1e23d197a1b90d399b1dd6ae5cde880ec60bbd02df57103333f51ef04',
#    'tissue': 'lung',
#    'anatomy': 'UBERON:0002048',
#    'cmap_id': 'CPC006_CORL23_6H:BRD-A35108200-001-04-7:10',
#    'disease': 'lung cancer',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC006_CORL23_6H_F09_dexamethasone_10uM.tsv',
#    'local_id': 'CPC006_CORL23_6H_F09_dexamethasone_10uM',
#    'cell_line': 'CORL23',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '6 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-08',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC006_CORL23_6H_F09_dexamethasone_10uM.tsv',
#    'size_in_bytes': 345096,
#    'uncompressed_size_in_bytes': 345096}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': 'eff5747d-526b-52fd-91b5-923237f886c0',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': '7d56548a73857feb71f9d61ae0fdfcf3',
#    'doid': 'DOID:1324',
#    'sha256': '56e3e6cf111dcd007ad4f6bf08b79c0ebdebb25b48c971c4ed0b856f9918a3f7',
#    'tissue': 'lung',
#    'anatomy': 'UBERON:0002048',
#    'cmap_id': 'CPC006_H1299_6H:BRD-A69951442-001-01-3:10',
#    'disease': 'lung cancer',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC006_H1299_6H_O03_dexamethasone_10uM.tsv',
#    'local_id': 'CPC006_H1299_6H_O03_dexamethasone_10uM',
#    'cell_line': 'H1299',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '6 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-08',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC006_H1299_6H_O03_dexamethasone_10uM.tsv',
#    'size_in_bytes': 345550,
#    'uncompressed_size_in_bytes': 345550}},
#  {'$validator': '/dcic/signature-commons-schema/v5/core/signature.json',
#   'id': 'f43c14bc-90b7-5baa-a6ae-cb21e3e8e833',
#   'library': '54198d6e-fe17-5ef8-91ac-02b425761653',
#   'meta': {'md5': 'd434424ad5dbe6b3cc1abba9d5bb913d',
#    'doid': 'DOID:1324',
#    'sha256': '312612b0df9467c120475d1076e7c6f41997fca37c48d90d9fa45b927c69df75',
#    'tissue': 'lung',
#    'anatomy': 'UBERON:0002048',
#    'cmap_id': 'CPC006_CORL23_6H:BRD-A69951442-001-01-3:10',
#    'disease': 'lung cancer',
#    'version': 1,
#    'filename': 'L1000_LINCS_DCIC_CPC006_CORL23_6H_O03_dexamethasone_10uM.tsv',
#    'local_id': 'CPC006_CORL23_6H_O03_dexamethasone_10uM',
#    'cell_line': 'CORL23',
#    'pert_dose': '10 uM',
#    'pert_name': 'dexamethasone',
#    'pert_time': '6 h',
#    'pert_type': 'Chemical',
#    '$validator': 'https://raw.githubusercontent.com/MaayanLab/sigcom-lincs/main/validators/l1000_signatures.json',
#    'data_level': 5,
#    'pubchem_id': 5743,
#    'creation_time': '2021-05-08',
#    'persistent_id': 'https://lincs-dcic.s3.amazonaws.com/LINCS-sigs-2021/cd/cp/L1000_LINCS_DCIC_CPC006_CORL23_6H_O03_dexamethasone_10uM.tsv',
#    'size_in_bytes': 345667,
#    'uncompressed_size_in_bytes': 345667}}]

# %%
len(dex_signatures)
# Out:
# 467

# %%
table = pd.DataFrame([dex_signatures[0]['meta']])
for i in range(1, len(dex_signatures)):
    row = pd.DataFrame([dex_signatures[i]['meta']])
    table = pd.concat([table, row])

# %%
table.reset_index()
# Out:
#      index                               md5       doid  \
# 0        0  f8550c4ae170d84a47b2e315d75bfc64  DOID:1324
# 1        0  2bae292caf243ab06cdca3d23e060937  DOID:1324
# 2        0  e18ffc8a744b1db9a2faa77b0ff21073  DOID:1324
# 3        0  bd9869e44fcf0e72e9b4629cf1a59e95  DOID:1324
# 4        0  7c016384dc50ba68fb56184c071c2641  DOID:1324
# ..     ...                               ...        ...
# 462      0  8cbd9e21980dd5fcb4adb3c9dc6f453e  DOID:4001
# 463      0  1e7732b55c746e622276ef9b57c90442  DOID:1324
# 464      0  61480526868312cd2af17d580986193b  DOID:1324
# 465      0  7d56548a73857feb71f9d61ae0fdfcf3  DOID:1324
# 466      0  d434424ad5dbe6b3cc1abba9d5bb913d  DOID:1324
#
#                                                 sha256 tissue         anatomy  \
# 0    3c4397b55647dea09adaa12853f102ceafdf5ca120ad8c...   lung  UBERON:0002048
# 1    b3affb611b35f05d83e2942f2724aac78c39fae18121e9...   lung  UBERON:0002048
# 2    eb7b7b6d55ffa3b7449fc032cc0f76e936788c4b2a856d...   lung  UBERON:0002048
# 3    378fbed02e85b3421aea70b7b7224f955a7d2be5bcb4f5...   lung  UBERON:0002048
# 4    2c25590f9a53fb807623976f7108a2f088759070891043...   lung  UBERON:0002048
# ..                                                 ...    ...             ...
# 462  bc95abbbb41476e463233b53d751f2287585c1010bbfbf...  ovary  UBERON:0000992
# 463  ad65aafb2d7bb4d93efa47c60d708ab18ea4f05d6bdf1f...   lung  UBERON:0002048
# 464  829cdeb1e23d197a1b90d399b1dd6ae5cde880ec60bbd0...   lung  UBERON:0002048
# 465  56e3e6cf111dcd007ad4f6bf08b79c0ebdebb25b48c971...   lung  UBERON:0002048
# 466  312612b0df9467c120475d1076e7c6f41997fca37c48d9...   lung  UBERON:0002048
#
#                                         cmap_id            disease  version  \
# 0                          LKCP002_A549_48H:E08        lung cancer        1
# 1                          LKCP002_A549_48H:E07        lung cancer        1
# 2                          LKCP002_A549_24H:E08        lung cancer        1
# 3                           LKCP002_A549_6H:E09        lung cancer        1
# 4                           LKCP002_A549_6H:E07        lung cancer        1
# ..                                          ...                ...      ...
# 462   CPC006_EFO27_6H:BRD-A35108200-001-04-7:10  ovarian carcinoma        1
# 463    CPC006_DV90_6H:BRD-A69951442-001-01-3:10        lung cancer        1
# 464  CPC006_CORL23_6H:BRD-A35108200-001-04-7:10        lung cancer        1
# 465   CPC006_H1299_6H:BRD-A69951442-001-01-3:10        lung cancer        1
# 466  CPC006_CORL23_6H:BRD-A69951442-001-01-3:10        lung cancer        1
#
#                                               filename  ... pert_type  \
# 0    L1000_LINCS_DCIC_LKCP002_A549_48H_E08_dexameth...  ...  Chemical
# 1    L1000_LINCS_DCIC_LKCP002_A549_48H_E07_dexameth...  ...  Chemical
# 2    L1000_LINCS_DCIC_LKCP002_A549_24H_E08_dexameth...  ...  Chemical
# 3    L1000_LINCS_DCIC_LKCP002_A549_6H_E09_dexametha...  ...  Chemical
# 4    L1000_LINCS_DCIC_LKCP002_A549_6H_E07_dexametha...  ...  Chemical
# ..                                                 ...  ...       ...
# 462  L1000_LINCS_DCIC_CPC006_EFO27_6H_F09_dexametha...  ...  Chemical
# 463  L1000_LINCS_DCIC_CPC006_DV90_6H_O03_dexamethas...  ...  Chemical
# 464  L1000_LINCS_DCIC_CPC006_CORL23_6H_F09_dexameth...  ...  Chemical
# 465  L1000_LINCS_DCIC_CPC006_H1299_6H_O03_dexametha...  ...  Chemical
# 466  L1000_LINCS_DCIC_CPC006_CORL23_6H_O03_dexameth...  ...  Chemical
#
#                                             $validator data_level pubchem_id  \
# 0    https://raw.githubusercontent.com/MaayanLab/si...          5       5743
# 1    https://raw.githubusercontent.com/MaayanLab/si...          5       5743
# 2    https://raw.githubusercontent.com/MaayanLab/si...          5       5743
# 3    https://raw.githubusercontent.com/MaayanLab/si...          5       5743
# 4    https://raw.githubusercontent.com/MaayanLab/si...          5       5743
# ..                                                 ...        ...        ...
# 462  https://raw.githubusercontent.com/MaayanLab/si...          5       5743
# 463  https://raw.githubusercontent.com/MaayanLab/si...          5       5743
# 464  https://raw.githubusercontent.com/MaayanLab/si...          5       5743
# 465  https://raw.githubusercontent.com/MaayanLab/si...          5       5743
# 466  https://raw.githubusercontent.com/MaayanLab/si...          5       5743
#
#     creation_time                                      persistent_id  \
# 0      2021-05-19  https://lincs-dcic.s3.amazonaws.com/LINCS-sigs...
# 1      2021-05-19  https://lincs-dcic.s3.amazonaws.com/LINCS-sigs...
# 2      2021-05-19  https://lincs-dcic.s3.amazonaws.com/LINCS-sigs...
# 3      2021-05-19  https://lincs-dcic.s3.amazonaws.com/LINCS-sigs...
# 4      2021-05-19  https://lincs-dcic.s3.amazonaws.com/LINCS-sigs...
# ..            ...                                                ...
# 462    2021-05-08  https://lincs-dcic.s3.amazonaws.com/LINCS-sigs...
# 463    2021-05-08  https://lincs-dcic.s3.amazonaws.com/LINCS-sigs...
# 464    2021-05-08  https://lincs-dcic.s3.amazonaws.com/LINCS-sigs...
# 465    2021-05-08  https://lincs-dcic.s3.amazonaws.com/LINCS-sigs...
# 466    2021-05-08  https://lincs-dcic.s3.amazonaws.com/LINCS-sigs...
#
#     size_in_bytes  uncompressed_size_in_bytes  $counter $download_counter
# 0          217006                      217006       NaN               NaN
# 1          217203                      217203       NaN               NaN
# 2          216777                      216777       NaN               NaN
# 3          217204                      217204       NaN               NaN
# 4          217082                      217082       NaN               NaN
# ..            ...                         ...       ...               ...
# 462        345103                      345103       NaN               NaN
# 463        345162                      345162       NaN               NaN
# 464        345096                      345096       NaN               NaN
# 465        345550                      345550       NaN               NaN
# 466        345667                      345667       NaN               NaN
#
# [467 rows x 25 columns]

# %%
table.columns
# Out:
# Index(['md5', 'doid', 'sha256', 'tissue', 'anatomy', 'cmap_id', 'disease',
#        'version', 'filename', 'local_id', 'cell_line', 'pert_dose',
#        'pert_name', 'pert_time', 'pert_type', '$validator', 'data_level',
#        'pubchem_id', 'creation_time', 'persistent_id', 'size_in_bytes',
#        'uncompressed_size_in_bytes', '$counter', '$download_counter'],
#       dtype='object')

# %%
table[['tissue', 'disease','local_id', 'cell_line','pert_dose','pert_name','pert_time','pert_type','pubchem_id','creation_time']]
# Out:
#    tissue            disease                                   local_id  \
# 0    lung        lung cancer  LKCP002_A549_48H_E08_dexamethasone_1.11uM
# 0    lung        lung cancer    LKCP002_A549_48H_E07_dexamethasone_10uM
# 0    lung        lung cancer  LKCP002_A549_24H_E08_dexamethasone_1.11uM
# 0    lung        lung cancer   LKCP002_A549_6H_E09_dexamethasone_0.12uM
# 0    lung        lung cancer     LKCP002_A549_6H_E07_dexamethasone_10uM
# ..    ...                ...                                        ...
# 0   ovary  ovarian carcinoma     CPC006_EFO27_6H_F09_dexamethasone_10uM
# 0    lung        lung cancer      CPC006_DV90_6H_O03_dexamethasone_10uM
# 0    lung        lung cancer    CPC006_CORL23_6H_F09_dexamethasone_10uM
# 0    lung        lung cancer     CPC006_H1299_6H_O03_dexamethasone_10uM
# 0    lung        lung cancer    CPC006_CORL23_6H_O03_dexamethasone_10uM
#
#    cell_line pert_dose      pert_name pert_time pert_type  pubchem_id  \
# 0       A549   1.11 uM  dexamethasone      48 h  Chemical        5743
# 0       A549     10 uM  dexamethasone      48 h  Chemical        5743
# 0       A549   1.11 uM  dexamethasone      24 h  Chemical        5743
# 0       A549   0.12 uM  dexamethasone       6 h  Chemical        5743
# 0       A549     10 uM  dexamethasone       6 h  Chemical        5743
# ..       ...       ...            ...       ...       ...         ...
# 0      EFO27     10 uM  dexamethasone       6 h  Chemical        5743
# 0       DV90     10 uM  dexamethasone       6 h  Chemical        5743
# 0     CORL23     10 uM  dexamethasone       6 h  Chemical        5743
# 0      H1299     10 uM  dexamethasone       6 h  Chemical        5743
# 0     CORL23     10 uM  dexamethasone       6 h  Chemical        5743
#
#    creation_time
# 0     2021-05-19
# 0     2021-05-19
# 0     2021-05-19
# 0     2021-05-19
# 0     2021-05-19
# ..           ...
# 0     2021-05-08
# 0     2021-05-08
# 0     2021-05-08
# 0     2021-05-08
# 0     2021-05-08
#
# [467 rows x 10 columns]

# %%
'''API_URL = "https://maayanlab.cloud/sigcom-lincs/metadata-api/signatures/value_count"

payload = {
    "where": {
        "meta.pert_name":  "dexamethasone"
    }
}

res = requests.get(API_URL, params={"filter": json.dumps(payload)})
results = res.json()

print(json.dumps(results, indent=2))'''
# Out:
# 'API_URL = "https://maayanlab.cloud/sigcom-lincs/metadata-api/signatures/value_count"\n\npayload = {\n    "where": {\n        "meta.pert_name":  "dexamethasone"\n    }\n}\n\nres = requests.get(API_URL, params={"filter": json.dumps(payload)})\nresults = res.json()\n\nprint(json.dumps(results, indent=2))'
